# %%
import pandas as pd

mood_dataset = pd.read_csv("./mood_dataset.csv")
tracks_dataset = pd.read_csv("./spotify_tracks_dataset.csv")
lyrics_dataset = pd.read_csv("./songs_with_attributes_and_lyrics.csv")
print(mood_dataset.shape)
mood_dataset.columns
print(mood_dataset[mood_dataset["labels"] == 3].shape)
# Out:
# (277938, 15)
# (42386, 15)

# %%
print(tracks_dataset.shape)
tracks_dataset.columns
# 1. Buscamos filas donde el artista contenga "Johnny Cash" y la canción contenga "Hurt"
# Usamos case=False para que no importe si escribes en mayúsculas o minúsculas
busqueda = tracks_dataset[
    tracks_dataset['artists'].str.contains('Othman', case=False, na=False) & 
    tracks_dataset['track_name'].str.contains('', case=False, na=False)
]

# 2. Mostramos solo las columnas que nos interesan para comparar con Librosa
columnas_interes = ['artists', 'track_name', 'danceability', 'energy', 'loudness', 
                     'speechiness', 'acousticness', 'instrumentalness', 'valence', 'tempo', "duration_ms", "popularity"]

# 3. Visualizamos el resultado
busqueda[columnas_interes]
tracks_dataset[tracks_dataset['track_genre'] == 'dubstep']
# Out:
# (114000, 21)
#        Unnamed: 0                track_id                artists  \
# 29000       29000  5zviMoAeuerK1Rd58qXASv   ILLENIUM;Teddy Swims
# 29001       29001  6pooRNiLyYpxZeIA5kJ5EX   ILLENIUM;Jon Bellion
# 29002       29002  7Bx0oBgnEfVR2bCs6Aul0X           ILLENIUM;MAX
# 29003       29003  2eFjKl5cyPPYElDByCh6Tb     ILLENIUM;iann dior
# 29004       29004  39glqzRVRAy4vq3PqeTGb8  SLANDER;Dylan Matthew
# ...           ...                     ...                    ...
# 29995       29995  7beAh9FEDhV8VUQ39fwDyf       Ray Volpe;Soltan
# 29996       29996  3pnCeZNsoRXi2b5DbsOpqV        Jason Ross;RUNN
# 29997       29997  2p4Y8c7O0Tm48Zk6IAWcTo                SLANDER
# 29998       29998  5gQI9ccczclMrKfPnfxpkD            Dirt Monkey
# 29999       29999  5ruT2dWSHtML4esT7doTzt                Borgore
#
#                                       album_name  \
# 29000                    All That Really Matters
# 29001  Good Things Fall Apart (with Jon Bellion)
# 29002                                  Worst Day
# 29003                                 First Time
# 29004                               Love Is Gone
# ...                                          ...
# 29995                               Elbow Grease
# 29996                                      Atlas
# 29997                                     Thrive
# 29998                                Primatology
# 29999                 Ruined Dubstep - EP, Pt. 1
#
#                                       track_name  popularity  duration_ms  \
# 29000                    All That Really Matters          70       244235
# 29001  Good Things Fall Apart (with Jon Bellion)          64       216668
# 29002                                  Worst Day           0       167274
# 29003                                 First Time          62       165779
# 29004                               Love Is Gone          67       256042
# ...                                          ...         ...          ...
# 29995                               Elbow Grease          39       213600
# 29996                  More To Life (feat. RUNN)          36       224181
# 29997                                Second Life          41       376615
# 29998                                 High Grade          22       115201
# 29999                             Cry Me a River          21       278851
#
#        explicit  danceability  energy  ...  loudness  mode  speechiness  \
# 29000     False         0.352   0.666  ...    -4.909     1       0.0512
# 29001     False         0.643   0.594  ...    -5.453     1       0.0318
# 29002     False         0.534   0.839  ...    -2.951     1       0.0530
# 29003     False         0.526   0.667  ...    -5.451     1       0.0437
# 29004     False         0.452   0.465  ...   -10.006     0       0.0344
# ...         ...           ...     ...  ...       ...   ...          ...
# 29995     False         0.594   0.992  ...    -1.800     1       0.0677
# 29996     False         0.551   0.812  ...    -5.186     1       0.0482
# 29997     False         0.706   0.857  ...    -7.419     0       0.0397
# 29998     False         0.709   0.975  ...    -1.587     0       0.1670
# 29999      True         0.536   0.416  ...   -10.004     0       0.3500
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 29000       0.11700          0.000002    0.0934   0.2270  169.965
# 29001       0.01280          0.000000    0.1180   0.4420  144.033
# 29002       0.06980          0.000000    0.2640   0.5760  155.002
# 29003       0.05050          0.000000    0.3210   0.4300  155.085
# 29004       0.05890          0.000524    0.0950   0.0832  149.586
# ...             ...               ...       ...      ...      ...
# 29995       0.00311          0.693000    0.1700   0.4170  150.052
# 29996       0.22700          0.000004    0.1220   0.3840  110.020
# 29997       0.00435          0.866000    0.1010   0.3000  129.994
# 29998       0.03960          0.498000    0.3310   0.3040  149.929
# 29999       0.16800          0.001480    0.0715   0.1340   67.922
#
#        time_signature  track_genre
# 29000               4      dubstep
# 29001               4      dubstep
# 29002               4      dubstep
# 29003               4      dubstep
# 29004               4      dubstep
# ...               ...          ...
# 29995               4      dubstep
# 29996               4      dubstep
# 29997               4      dubstep
# 29998               4      dubstep
# 29999               4      dubstep
#
# [1000 rows x 21 columns]

# %%
print(lyrics_dataset.shape)
lyrics_dataset.columns
# Out:
# (955320, 17)
# Index(['id', 'name', 'album_name', 'artists', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'lyrics'],
#       dtype='str')
